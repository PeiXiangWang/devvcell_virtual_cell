# %% [markdown]
# # 02 OT Teacher
# Run `python -m src.ot_teacher.run_moscot --config configs/ot_teacher.yaml`, `python -m src.ot_teacher.run_wot --config configs/ot_teacher.yaml`, and `python -m src.ot_teacher.build_teacher --config configs/ot_teacher.yaml`.
